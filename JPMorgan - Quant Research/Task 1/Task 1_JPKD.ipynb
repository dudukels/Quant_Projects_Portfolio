# %% [markdown]
# JP Mogan - Quant Research Task 1
# John Paul K. Dulay
# MS Financial Engineering - Claremont Graduate University
# 08/13/2023

# %%
# importing needed libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reads the raw CSV file
nat_gas_df = pd.read_csv('Nat_Gas.csv')

df_datetime_index = pd.to_datetime(nat_gas_df['Dates']) #convert dates to datetime objects
nat_gas_df = nat_gas_df.set_index(df_datetime_index).drop('Dates', axis=1) #set datetime series as index and drop the 'Dates' column

nat_gas_df
# Out:
#             Prices
# Dates
# 2020-10-31   10.10
# 2020-11-30   10.30
# 2020-12-31   11.00
# 2021-01-31   10.90
# 2021-02-28   10.90
# 2021-03-31   10.90
# 2021-04-30   10.40
# 2021-05-31    9.84
# 2021-06-30   10.00
# 2021-07-31   10.10
# 2021-08-31   10.30
# 2021-09-30   10.20
# 2021-10-31   10.10
# 2021-11-30   11.20
# 2021-12-31   11.40
# 2022-01-31   11.50
# 2022-02-28   11.80
# 2022-03-31   11.50
# 2022-04-30   10.70
# 2022-05-31   10.70
# 2022-06-30   10.40
# 2022-07-31   10.50
# 2022-08-31   10.40
# 2022-09-30   10.80
# 2022-10-31   11.00
# 2022-11-30   11.60
# 2022-12-31   11.60
# 2023-01-31   12.10
# 2023-02-28   11.70
# 2023-03-31   12.00
# 2023-04-30   11.50
# 2023-05-31   11.20
# 2023-06-30   10.90
# 2023-07-31   11.40
# 2023-08-31   11.10
# 2023-09-30   11.50
# 2023-10-31   11.80
# 2023-11-30   12.20
# 2023-12-31   12.80
# 2024-01-31   12.60
# 2024-02-29   12.40
# 2024-03-31   12.70
# 2024-04-30   12.10
# 2024-05-31   11.40
# 2024-06-30   11.50
# 2024-07-31   11.60
# ...

# %%
nat_gas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 48 entries, 2020-10-31 to 2024-09-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Prices  48 non-null     float64
# dtypes: float64(1)
# memory usage: 768.0 bytes

# %%
# plot data
plt.figure(figsize=(10,3),dpi=200)
plt.scatter(nat_gas_df.index, nat_gas_df['Prices'])
plt.xlabel('Dates')
plt.ylabel('Purchase Price of Natural Gas')

# https://dataplotplus.com/change-datetime-tick-label-frequency-matplotlib-plots/
# Out:
# Text(0, 0.5, 'Purchase Price of Natural Gas')

# %% [markdown]
# will need to deploy machine learning python package (linear regression?) that takes in the above raw data and outputs an estimated price for any past and future dates
#
# final product:
# f( date ) = price estimate

# %%
# Linear Regression Model
# https://www.kaggle.com/code/ryanholbrook/linear-regression-with-time-series

#time step feature - analysis 1
nat_gas_df['Time'] = np.arange(len(nat_gas_df.index))

nat_gas_df
# Out:
#             Prices  Lag_1  Time
# Dates
# 2020-10-31   10.10    NaN     0
# 2020-11-30   10.30  10.10     1
# 2020-12-31   11.00  10.30     2
# 2021-01-31   10.90  11.00     3
# 2021-02-28   10.90  10.90     4
# 2021-03-31   10.90  10.90     5
# 2021-04-30   10.40  10.90     6
# 2021-05-31    9.84  10.40     7
# 2021-06-30   10.00   9.84     8
# 2021-07-31   10.10  10.00     9
# 2021-08-31   10.30  10.10    10
# 2021-09-30   10.20  10.30    11
# 2021-10-31   10.10  10.20    12
# 2021-11-30   11.20  10.10    13
# 2021-12-31   11.40  11.20    14
# 2022-01-31   11.50  11.40    15
# 2022-02-28   11.80  11.50    16
# 2022-03-31   11.50  11.80    17
# 2022-04-30   10.70  11.50    18
# 2022-05-31   10.70  10.70    19
# 2022-06-30   10.40  10.70    20
# 2022-07-31   10.50  10.40    21
# 2022-08-31   10.40  10.50    22
# 2022-09-30   10.80  10.40    23
# 2022-10-31   11.00  10.80    24
# 2022-11-30   11.60  11.00    25
# 2022-12-31   11.60  11.60    26
# 2023-01-31   12.10  11.60    27
# ...

# %%
plt.style.use("seaborn-whitegrid")
plt.rc(
    "figure",
    autolayout=True,
    figsize=(11, 4),
    titlesize=18,
    titleweight='bold',
)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)
# %config InlineBackend.figure_format = 'retina'

fig, ax = plt.subplots()
ax.plot('Time', 'Prices', data=nat_gas_df, color='0.75')
ax = sns.regplot(x='Time', y='Prices', data=nat_gas_df, ci=None, scatter_kws=dict(color='0.25'))
ax.set_title('Time Plot of Natural Gas Contract Prices');
# Out:
# C:\Users\JUAN PABLO REYES\AppData\Local\Temp\ipykernel_5876\1467198687.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")

# %%
from sklearn.linear_model import LinearRegression

# Training data
X = nat_gas_df.loc[:, ['Time']]  # features - isolated 'Time' feature into a dataframe
y = nat_gas_df.loc[:, 'Prices']  # target - isolated 'Prices' target into a series

# Train the model
model = LinearRegression()
model.fit(X, y)

# Store the fitted values as a time series with the same time index as
# the training data
y_pred = pd.DataFrame(model.predict(X), index=X.index, columns=['Prices Estimated'])

y_pred['Time'] = np.arange(len(y_pred.index)) # created the time-step feature

y_pred
# Out:
#             Prices Estimated  Time
# Dates
# 2020-10-31         10.290272     0
# 2020-11-30         10.329285     1
# 2020-12-31         10.368299     2
# 2021-01-31         10.407312     3
# 2021-02-28         10.446325     4
# 2021-03-31         10.485338     5
# 2021-04-30         10.524352     6
# 2021-05-31         10.563365     7
# 2021-06-30         10.602378     8
# 2021-07-31         10.641391     9
# 2021-08-31         10.680405    10
# 2021-09-30         10.719418    11
# 2021-10-31         10.758431    12
# 2021-11-30         10.797444    13
# 2021-12-31         10.836458    14
# 2022-01-31         10.875471    15
# 2022-02-28         10.914484    16
# 2022-03-31         10.953497    17
# 2022-04-30         10.992510    18
# 2022-05-31         11.031524    19
# 2022-06-30         11.070537    20
# 2022-07-31         11.109550    21
# 2022-08-31         11.148563    22
# 2022-09-30         11.187577    23
# 2022-10-31         11.226590    24
# ...

# %%
# trying to compare the above plot with y_pred

plt.style.use("seaborn-whitegrid")
plt.rc(
    "figure",
    autolayout=True,
    figsize=(11, 4),
    titlesize=18,
    titleweight='bold',
)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)
# %config InlineBackend.figure_format = 'retina'

fig, ax = plt.subplots()

ax.plot('Time', 'Prices', data=nat_gas_df, color='0.75')
ax = sns.regplot(x='Time', y='Prices', data=nat_gas_df, ci=None, scatter_kws=dict(color='0.25'))

#plot the linear regression output yped
ax.plot('Time', 'Prices Estimated', data=y_pred, color='red', linewidth=1)

ax.set_title('Time Plot of Natural Gas Contract Prices');
# Out:
# C:\Users\JUAN PABLO REYES\AppData\Local\Temp\ipykernel_5876\876720765.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")

# %%
# lag feature - analysis 1
nat_gas_df['Lag_1'] = nat_gas_df['Prices'].shift(1)
nat_gas_df = nat_gas_df.reindex(columns=['Prices', 'Lag_1'])

nat_gas_df
# Out:
#             Prices  Lag_1
# Dates
# 2020-10-31   10.10    NaN
# 2020-11-30   10.30  10.10
# 2020-12-31   11.00  10.30
# 2021-01-31   10.90  11.00
# 2021-02-28   10.90  10.90
# 2021-03-31   10.90  10.90
# 2021-04-30   10.40  10.90
# 2021-05-31    9.84  10.40
# 2021-06-30   10.00   9.84
# 2021-07-31   10.10  10.00
# 2021-08-31   10.30  10.10
# 2021-09-30   10.20  10.30
# 2021-10-31   10.10  10.20
# 2021-11-30   11.20  10.10
# 2021-12-31   11.40  11.20
# 2022-01-31   11.50  11.40
# 2022-02-28   11.80  11.50
# 2022-03-31   11.50  11.80
# 2022-04-30   10.70  11.50
# 2022-05-31   10.70  10.70
# 2022-06-30   10.40  10.70
# 2022-07-31   10.50  10.40
# 2022-08-31   10.40  10.50
# 2022-09-30   10.80  10.40
# 2022-10-31   11.00  10.80
# 2022-11-30   11.60  11.00
# 2022-12-31   11.60  11.60
# 2023-01-31   12.10  11.60
# 2023-02-28   11.70  12.10
# 2023-03-31   12.00  11.70
# 2023-04-30   11.50  12.00
# 2023-05-31   11.20  11.50
# 2023-06-30   10.90  11.20
# 2023-07-31   11.40  10.90
# ...

# %%
nat_gas_df['Lag_1'] = nat_gas_df['Prices'].shift(1)
nat_gas_df = nat_gas_df.reindex(columns=['Prices', 'Lag_1'])

fig, ax = plt.subplots()
ax = sns.regplot(x='Lag_1', y='Prices', data=nat_gas_df, ci=None, scatter_kws=dict(color='0.25'))
ax.set_aspect('equal')
ax.set_title('Lag Plot of Natural Gas Contract Prices');

# %%
from sklearn.linear_model import LinearRegression

H = nat_gas_df.loc[:, ['Lag_1']] # isolate the Lag_1 feature into a Dataframe
H.dropna(inplace=True)  # drop missing values in the feature set
g = nat_gas_df.loc[:, 'Prices']  # isolate the target into a series
g, H = g.align(H, join='inner')  # drop corresponding values in target to align the indices of feature Dataframe


model = LinearRegression()
model.fit(H, g)

g_pred = pd.DataFrame(model.predict(H), index=H.index, columns=['Prices Estimated']) # g_pred index is aligned with g and H

g_pred = g_pred.join(nat_gas_df.loc[:, ['Lag_1']])

g_pred
# Out:
#             Prices Estimated  Lag_1
# Dates
# 2020-11-30         10.299702  10.10
# 2020-12-31         10.469819  10.30
# 2021-01-31         11.065227  11.00
# 2021-02-28         10.980169  10.90
# 2021-03-31         10.980169  10.90
# 2021-04-30         10.980169  10.90
# 2021-05-31         10.554877  10.40
# 2021-06-30         10.078551   9.84
# 2021-07-31         10.214644  10.00
# 2021-08-31         10.299702  10.10
# 2021-09-30         10.469819  10.30
# 2021-10-31         10.384761  10.20
# 2021-11-30         10.299702  10.10
# 2021-12-31         11.235344  11.20
# 2022-01-31         11.405460  11.40
# 2022-02-28         11.490519  11.50
# 2022-03-31         11.745693  11.80
# 2022-04-30         11.490519  11.50
# 2022-05-31         10.810052  10.70
# 2022-06-30         10.810052  10.70
# 2022-07-31         10.554877  10.40
# 2022-08-31         10.639936  10.50
# 2022-09-30         10.554877  10.40
# 2022-10-31         10.895110  10.80
# 2022-11-30         11.065227  11.00
# ...

# %%
# trying to compare the above plot with g_pred

nat_gas_df['Lag_1'] = nat_gas_df['Prices'].shift(1)
nat_gas_df = nat_gas_df.reindex(columns=['Prices', 'Lag_1'])


fig, ax = plt.subplots()
ax = sns.regplot(x='Lag_1', y='Prices', data=nat_gas_df, ci=None, scatter_kws=dict(color='0.25'))

# plot g_pred
ax.plot('Lag_1', 'Prices Estimated', data=g_pred, color='red', linewidth=0.5)

ax.set_aspect('equal')
ax.set_title('Lag Plot of Natural Gas Contract Prices');

# %%
# the code below is an exercise based on Tunnel Traffic example
# https://www.kaggle.com/code/ryanholbrook/linear-regression-with-time-series

# %%
from pathlib import Path
from warnings import simplefilter

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

simplefilter("ignore")  # ignore warnings to clean up output cells

# Set Matplotlib defaults
plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True, figsize=(11, 4))
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)
plot_params = dict(
    color="0.75",
    style=".-",
    markeredgecolor="0.25",
    markerfacecolor="0.25",
    legend=False,
)
# %config InlineBackend.figure_format = 'retina'

df = pd.read_csv('Nat_Gas.csv', parse_dates=["Dates"]) #parse_dates converts the Dates column into datetime object


# Create a time series in Pandas by setting the index to a date
# column. We parsed "Day" as a date type by using `parse_dates` when
# loading the data.
df = df.set_index("Dates") # set the Dates column as the index


# By default, Pandas creates a `DatetimeIndex` with dtype `Timestamp`
# (equivalent to `np.datetime64`, representing a time series as a
# sequence of measurements taken at single moments. A `PeriodIndex`,
# on the other hand, represents a time series as a sequence of
# quantities accumulated over periods of time. Periods are often
# easier to work with, so that's what we'll use in this course.
df.to_period() # emphasizes the periodicity of the dataframe
# Out:
#          Prices
# Dates
# 2020-10   10.10
# 2020-11   10.30
# 2020-12   11.00
# 2021-01   10.90
# 2021-02   10.90
# 2021-03   10.90
# 2021-04   10.40
# 2021-05    9.84
# 2021-06   10.00
# 2021-07   10.10
# 2021-08   10.30
# 2021-09   10.20
# 2021-10   10.10
# 2021-11   11.20
# 2021-12   11.40
# 2022-01   11.50
# 2022-02   11.80
# 2022-03   11.50
# 2022-04   10.70
# 2022-05   10.70
# 2022-06   10.40
# 2022-07   10.50
# 2022-08   10.40
# 2022-09   10.80
# 2022-10   11.00
# 2022-11   11.60
# 2022-12   11.60
# 2023-01   12.10
# 2023-02   11.70
# 2023-03   12.00
# 2023-04   11.50
# 2023-05   11.20
# 2023-06   10.90
# 2023-07   11.40
# 2023-08   11.10
# 2023-09   11.50
# 2023-10   11.80
# 2023-11   12.20
# 2023-12   12.80
# 2024-01   12.60
# 2024-02   12.40
# 2024-03   12.70
# 2024-04   12.10
# 2024-05   11.40
# 2024-06   11.50
# 2024-07   11.60
# 2024-08   11.50
# 2024-09   11.80

# %%
# time-step feature - analysis 2 

df['Time'] = np.arange(len(df.index))

df
# Out:
#             Prices  Time
# Dates
# 2020-10-31   10.10     0
# 2020-11-30   10.30     1
# 2020-12-31   11.00     2
# 2021-01-31   10.90     3
# 2021-02-28   10.90     4
# 2021-03-31   10.90     5
# 2021-04-30   10.40     6
# 2021-05-31    9.84     7
# 2021-06-30   10.00     8
# 2021-07-31   10.10     9
# 2021-08-31   10.30    10
# 2021-09-30   10.20    11
# 2021-10-31   10.10    12
# 2021-11-30   11.20    13
# 2021-12-31   11.40    14
# 2022-01-31   11.50    15
# 2022-02-28   11.80    16
# 2022-03-31   11.50    17
# 2022-04-30   10.70    18
# 2022-05-31   10.70    19
# 2022-06-30   10.40    20
# 2022-07-31   10.50    21
# 2022-08-31   10.40    22
# 2022-09-30   10.80    23
# 2022-10-31   11.00    24
# 2022-11-30   11.60    25
# 2022-12-31   11.60    26
# 2023-01-31   12.10    27
# 2023-02-28   11.70    28
# 2023-03-31   12.00    29
# 2023-04-30   11.50    30
# 2023-05-31   11.20    31
# 2023-06-30   10.90    32
# 2023-07-31   11.40    33
# 2023-08-31   11.10    34
# ...

# %%
from sklearn.linear_model import LinearRegression

# Training data
X = df.loc[:, ['Time']]  # features
y = df.loc[:, 'Prices']  # target

# Train the model
model = LinearRegression()
model.fit(X, y)

# Store the fitted values as a time series with the same time index as
# the training data
y_pred = pd.Series(model.predict(X), index=X.index)

y_pred
# Out:
# Dates
# 2020-10-31    10.290272
# 2020-11-30    10.329285
# 2020-12-31    10.368299
# 2021-01-31    10.407312
# 2021-02-28    10.446325
# 2021-03-31    10.485338
# 2021-04-30    10.524352
# 2021-05-31    10.563365
# 2021-06-30    10.602378
# 2021-07-31    10.641391
# 2021-08-31    10.680405
# 2021-09-30    10.719418
# 2021-10-31    10.758431
# 2021-11-30    10.797444
# 2021-12-31    10.836458
# 2022-01-31    10.875471
# 2022-02-28    10.914484
# 2022-03-31    10.953497
# 2022-04-30    10.992510
# 2022-05-31    11.031524
# 2022-06-30    11.070537
# 2022-07-31    11.109550
# 2022-08-31    11.148563
# 2022-09-30    11.187577
# 2022-10-31    11.226590
# 2022-11-30    11.265603
# 2022-12-31    11.304616
# 2023-01-31    11.343630
# 2023-02-28    11.382643
# 2023-03-31    11.421656
# 2023-04-30    11.460669
# 2023-05-31    11.499683
# 2023-06-30    11.538696
# 2023-07-31    11.577709
# 2023-08-31    11.616722
# 2023-09-30    11.655736
# 2023-10-31    11.694749
# 2023-11-30    11.733762
# ...

# %%
X
# Out:
#             Time
# Dates
# 2020-10-31     0
# 2020-11-30     1
# 2020-12-31     2
# 2021-01-31     3
# 2021-02-28     4
# 2021-03-31     5
# 2021-04-30     6
# 2021-05-31     7
# 2021-06-30     8
# 2021-07-31     9
# 2021-08-31    10
# 2021-09-30    11
# 2021-10-31    12
# 2021-11-30    13
# 2021-12-31    14
# 2022-01-31    15
# 2022-02-28    16
# 2022-03-31    17
# 2022-04-30    18
# 2022-05-31    19
# 2022-06-30    20
# 2022-07-31    21
# 2022-08-31    22
# 2022-09-30    23
# 2022-10-31    24
# 2022-11-30    25
# 2022-12-31    26
# 2023-01-31    27
# 2023-02-28    28
# 2023-03-31    29
# 2023-04-30    30
# 2023-05-31    31
# 2023-06-30    32
# 2023-07-31    33
# 2023-08-31    34
# 2023-09-30    35
# 2023-10-31    36
# 2023-11-30    37
# 2023-12-31    38
# 2024-01-31    39
# 2024-02-29    40
# 2024-03-31    41
# 2024-04-30    42
# 2024-05-31    43
# 2024-06-30    44
# 2024-07-31    45
# 2024-08-31    46
# 2024-09-30    47

# %%
# extend to 2025-09-30 for extrapolation

#create dataframe for extrapolation
X_extrapolate = pd.DataFrame(index=pd.date_range(start='2024-10-30', periods=12, freq='M') , columns=X.columns, data=np.arange(start=48,stop=60))


X_input = pd.concat([X, X_extrapolate],axis=0) # append X_extrapolate to X (features dataframe)

y_pred = pd.Series(model.predict(X_input), index=X_input.index)
# Out:
#             Time
# 2020-10-31     0
# 2020-11-30     1
# 2020-12-31     2
# 2021-01-31     3
# 2021-02-28     4
# 2021-03-31     5
# 2021-04-30     6
# 2021-05-31     7
# 2021-06-30     8
# 2021-07-31     9
# 2021-08-31    10
# 2021-09-30    11
# 2021-10-31    12
# 2021-11-30    13
# 2021-12-31    14
# 2022-01-31    15
# 2022-02-28    16
# 2022-03-31    17
# 2022-04-30    18
# 2022-05-31    19
# 2022-06-30    20
# 2022-07-31    21
# 2022-08-31    22
# 2022-09-30    23
# 2022-10-31    24
# 2022-11-30    25
# 2022-12-31    26
# 2023-01-31    27
# 2023-02-28    28
# 2023-03-31    29
# 2023-04-30    30
# 2023-05-31    31
# 2023-06-30    32
# 2023-07-31    33
# 2023-08-31    34
# 2023-09-30    35
# 2023-10-31    36
# 2023-11-30    37
# 2023-12-31    38
# 2024-01-31    39
# 2024-02-29    40
# 2024-03-31    41
# 2024-04-30    42
# 2024-05-31    43
# 2024-06-30    44
# 2024-07-31    45
# 2024-08-31    46
# 2024-09-30    47
# 2024-10-31    48
# 2024-11-30    49
# 2024-12-31    50
# ...

# %%
ax = y.plot(**plot_params)
ax = y_pred.plot(ax=ax, linewidth=3)
ax.set_ylabel('Prices')
ax.set_title('Time Plot of Natural Gas Contract Prices');

# %%
# lag feature - analysis 2

df['Lag_1'] = df['Prices'].shift(1)
df
# Out:
#             Prices  Time  Lag_1
# Dates
# 2020-10-31   10.10     0    NaN
# 2020-11-30   10.30     1  10.10
# 2020-12-31   11.00     2  10.30
# 2021-01-31   10.90     3  11.00
# 2021-02-28   10.90     4  10.90
# 2021-03-31   10.90     5  10.90
# 2021-04-30   10.40     6  10.90
# 2021-05-31    9.84     7  10.40
# 2021-06-30   10.00     8   9.84
# 2021-07-31   10.10     9  10.00
# 2021-08-31   10.30    10  10.10
# 2021-09-30   10.20    11  10.30
# 2021-10-31   10.10    12  10.20
# 2021-11-30   11.20    13  10.10
# 2021-12-31   11.40    14  11.20
# 2022-01-31   11.50    15  11.40
# 2022-02-28   11.80    16  11.50
# 2022-03-31   11.50    17  11.80
# 2022-04-30   10.70    18  11.50
# 2022-05-31   10.70    19  10.70
# 2022-06-30   10.40    20  10.70
# 2022-07-31   10.50    21  10.40
# 2022-08-31   10.40    22  10.50
# 2022-09-30   10.80    23  10.40
# 2022-10-31   11.00    24  10.80
# 2022-11-30   11.60    25  11.00
# 2022-12-31   11.60    26  11.60
# 2023-01-31   12.10    27  11.60
# ...

# %%
from sklearn.linear_model import LinearRegression

X = df.loc[:, ['Lag_1']] # isolate the Lag_1 feature into a dataframe
X.dropna(inplace=True)  # drop missing values in the feature set
y = df.loc[:, 'Prices']  # create the target
y, X = y.align(X, join='inner')  # drop corresponding values in target

model = LinearRegression()
model.fit(X, y)

y_pred = pd.Series(model.predict(X), index=X.index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[270], line 3
#       1 from sklearn.linear_model import LinearRegression
# ----> 3 X = df.loc[:, ['Lag_1']] # isolate the Lag_1 feature into a dataframe
#       4 X.dropna(inplace=True)  # drop missing values in the feature set
#       5 y = df.loc[:, 'Prices']  # create the target
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1256, in _LocIndexer._getitem_tuple(self, tup)
# ...

# %%
y_pred['2024-09-30']
# Out:
# 12.123894557823128

# %%
fig, ax = plt.subplots()
ax.plot(X['Lag_1'], y, '.', color='0.25')
ax.plot(X['Lag_1'], y_pred)
ax.set_aspect('equal')
ax.set_ylabel('Prices')
ax.set_xlabel('Lag_1')
ax.set_title('Lag Plot of Natural Gas Contract Prices');

# %%
# Trend
# https://www.kaggle.com/code/ryanholbrook/trend

from pathlib import Path
from warnings import simplefilter

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

simplefilter("ignore")  # ignore warnings to clean up output cells

# Set Matplotlib defaults
plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True, figsize=(11, 5))
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)
plot_params = dict(
    color="0.75",
    style=".-",
    markeredgecolor="0.25",
    markerfacecolor="0.25",
    legend=False,
)
# %config InlineBackend.figure_format = 'retina'


# Load dataset

df = pd.read_csv('Nat_Gas.csv', parse_dates=["Dates"])
df = df.set_index("Dates")

# %%
moving_average = df.rolling(
    window=10,       # 365-day window
    center=True,      # puts the average at the center of the window
    min_periods=1,  # choose about half the window size
).mean()              # compute the mean (could also do median, std, min, max, ...)

ax = df.plot(style=".", color="0.5")
moving_average.plot(
    ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False,
);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 48 entries, 2020-10-31 to 2024-09-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Prices  48 non-null     float64
# dtypes: float64(1)
# memory usage: 768.0 bytes
